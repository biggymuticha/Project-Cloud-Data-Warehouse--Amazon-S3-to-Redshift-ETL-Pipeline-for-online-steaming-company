# %%
## Execute scripts

# %%
# %run -i 'create_tables.py'
# Out:
# Checking existing tables to drop .....
# 7 tables droped.
# Creating tables....
# 7 tables created.

# %%
## Extract, transform and load the data

# %%
# %%time
# %run -i 'etl.py'
# Out:
# Scanning folders with json files.....
# s3://udacity-dend/song_data/A/A/A/
# s3://udacity-dend/song_data/A/A/B/
# s3://udacity-dend/song_data/A/A/C/
# s3://udacity-dend/song_data/A/A/D/
# s3://udacity-dend/song_data/A/A/E/
# s3://udacity-dend/song_data/A/A/F/
# s3://udacity-dend/song_data/A/A/G/
# s3://udacity-dend/song_data/A/A/H/
# s3://udacity-dend/song_data/A/A/I/
# s3://udacity-dend/song_data/A/A/J/
# s3://udacity-dend/song_data/A/A/K/
# s3://udacity-dend/song_data/A/A/L/
# s3://udacity-dend/song_data/A/A/M/
# s3://udacity-dend/song_data/A/A/N/
# s3://udacity-dend/song_data/A/A/O/
# s3://udacity-dend/song_data/A/A/P/
# s3://udacity-dend/song_data/A/A/Q/
# s3://udacity-dend/song_data/A/A/R/
# s3://udacity-dend/song_data/A/A/S/
# s3://udacity-dend/song_data/A/A/T/
# s3://udacity-dend/song_data/A/A/U/
# s3://udacity-dend/song_data/A/A/V/
# s3://udacity-dend/song_data/A/A/W/
# s3://udacity-dend/song_data/A/A/X/
# s3://udacity-dend/song_data/A/A/Y/
# ...
